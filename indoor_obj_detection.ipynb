# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.130  Python-3.12.4 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Setup complete  (8 CPUs, 15.8 GB RAM, 368.8/474.7 GB disk)

# %%
from ultralytics import YOLO
model = YOLO('yolo11n.pt')
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 6.87MB/s]

# %%
result = model.train(data='data.yaml', epochs = 50, imgsz=640)
# Out:
# Ultralytics 8.3.130  Python-3.12.4 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
model.predict(source=r"C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images", save=True)
# Out:
# image 1/107 C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images\1003.png: 480x640 3 doors, 81.8ms
# image 2/107 C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images\1014.png: 480x640 1 window, 20.3ms
# image 3/107 C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images\1015.png: 480x640 (no detections), 10.0ms
# image 4/107 C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images\1020.png: 480x640 1 openedDoor, 12.7ms
# image 5/107 C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images\1021.png: 480x640 (no detections), 11.8ms
# image 6/107 C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images\1023.png: 480x640 1 window, 1 chair, 20.3ms
# image 7/107 C:\Users\Admin\Desktop\PL\Deep_Learning\Indoor_Object_Detection\dataset\test\images\1026.png: 480x640 1 door, 3 windows, 3 couchs, 11.0ms
# ...
